# %%
from gensim.models import KeyedVectors
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
# import networkx as nx
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt
model = KeyedVectors.load_word2vec_format('清洗后文本.txt')

# %%
for key, value in model.most_similar('spintronics', topn=100000):
    print(key)
# Out:
# spintronic
# spin-based
# optoelectronics
# nanoelectronics
# magnetoelectronic
# magnetoelectronics
# spinelectronics
# valleytronics
# atomically-thin
# Spintronics
# spin-electronic
# devices
# MRAMs
# magnonics
# photonics
# valleytronic
# nanodevices
# nano-electronic
# nanoelectronic
# spin-transport
# optoelectronic
# ZrSiS
# ferromagnet/semiconductor
# Spintronic
# nano-devices
# semiconductor-based
# electronics
# nanomemory
# opto-
# all-electric
# MRAM
# spin-mediated
# magnetoelectricity
# nanomagnetism
# nano-engineering
# petahertz
# applications
# multiferroicity
# α-RuCl_3
# spin–valley
# silicene-based
# nanophotonics
# high-T_C
# ultra-high-density
# Co_3Sn_2S_2
# molecule-based
# straintronics
# HOTIs
# data-storage
# manganite-based
# quantum-information
# magneto-electronic
# proximitized
# magnetics
# transition-metal-doped
# spin-textured
# nano-oscillators
# spin-injection
# magnetism
# phononics
# nano-optoelectronics
# nano-optoelectronic
# FeRAM
# ...

# %%
# 假设 `model` 是你预训练好的模型对象
similar_words = [key for key, value in model.most_similar('ferroelectricity', topn=500)]

import re
# 定义匹配复杂化学式的正则表达式模式
chemical_formula_pattern = re.compile(r'\b[A-Z][a-z]?[A-Za-z0-9_\.]*\b')

# 存储提取的化学式
chemical_formulas = []

# 提取化学式
for word in similar_words:
    matches = chemical_formula_pattern.findall(word)
    for match in matches:
        # 过滤出有意义的化学式，忽略单个字符和数字
        if len(match) > 1 and re.search(r'[A-Za-z]', match):
            chemical_formulas.append(match)

# 去重
chemical_formulas = list(set(chemical_formulas))

# 打印所有提取到的化学式
print(chemical_formulas)
# Out:
# ['SmFeAsO', 'La_07Ce_03MnO_3', 'BiT', 'PbMg_1', 'La_2', 'Bi_4I_4', 'BFCO', 'Au_2Pb', 'Bi_1', 'LaVO_3', 'TbMnO_3', 'Ho_2Ti_2O_7', 'PMNT', 'Ba_08Sr_02TiO_3', 'CeNiSn', 'BNTO', 'Nb_2PdS_5', 'PCMO', 'YBa_2Cu_3O_z', 'LSCO', 'FeSCs', 'CeIrIn_5', 'BLFO', 'FICDW', 'FeTe', 'Ba_2LaSbO_6', 'La_2NiMnO_6', 'LFMR', 'LiV_2O_4', 'Electron', 'BCZT', 'RTFM', 'Zn', 'Ba_09Sr_01TiO_3', 'CrBr_3', 'BLFMO', 'AFLCs', 'UCoAl', 'CDW', 'Bi2201', 'BTO', 'CaMn_7O_12', 'CrI_3', 'Nd_05Sr_05MnO_3', 'BNdT', 'LuFe_2O_4', 'Curie', 'TbMn_2O_5', 'GdCu', 'Nd_2Zr_2O_7', 'Nd', 'BiSb', 'LaOFeAs', 'CePt_3Si', 'Magneto', 'BGFT_x', 'Dy', 'Na_3C_60', 'Fe_1', 'Co_2Y', 'Sr', 'YCrO3', 'Co_01Bi_2Se_3', 'UNiAl', 'HoMo_6S_8', 'Stoner', 'Ba_1', 'HoRh_4B_4', 'EFIS', 'PrOs_4Sb_12', 'LaTiO_3', 'BNKT', 'Gd', 'UNiGa', 'GaFeO_3', 'Aurivillius', 'RbFeF_3', 'LSFO', 'Bi_05Na_05TiO_3', 'LPCMO', 'Nb', 'SmB_6', 'CeRhIn_5', 'Ru1212', 'La_1875Ba_0125CuO_4', 'LHMO', 'Co_2MnGa', 'GP', 'GaMnAs', 'LiFeAs', 'KTaO_3', 'EuMn_2O_5', 'La_14Sr_16Mn_2O_7', 'Pb
# ...

# %%
# from pyvis.network import Network
# import networkx as nx
# import numpy as np

# # 定义需要计算相似性的词汇

# ferroelectricity = ['BaTiO3','PZT','PVDF','LiNbO3','BiFeO3','UNiGa', 'BaTiO_3', 
#             'GaFeO_3', 'La_07Ce_03MnO_3', 'BFO', 'BFCO', 'TbMnO_3', 'GdMnO_3', 'Nb', 
#             'Sr_2IrO_4', 'COAFM', 'PMNT', 'LHMO', 'Cu', 'PCMO', 'TaSe_2', 'Ferromagnetism',
#             'TlCrSe_2', 'EuMn_2O_5', 'Colossal', 'BiMnO_3', 'LuFeO_3', 'EuTiO_3', 'BFMO',
#             'Pr_06Ca_04MnO_3', 'Ferroelectrics', 'AFM', 'URhGe', 'Bi_095La_005FeO_3', 
#             'Ferroelectric', 'CDW', 'BaMnF_4', 'KCa_2Fe_4As_4F_2', 'LuFe_2O_4', 'BNT', 
#             'Sr_2FeMoO_6', 'BGFT_x', 'Tb_095Bi_005MnO_3', 'FM', 'YMnO_3', 'RuSr_2GdCu_2O_8', 
#             'PZT', 'MFTJs', 'BiFeO_3', 'SBN', 'HoMo_6S_8', 'EFIS', 'Sr_3Ir_2O_7', 'BNKT']
# application = ['sensors', 'actuators', 'filters', 'capacitors']
# mechanism = ['polarization', 'strain', 'capacitive', 'permittivity']
# structure = ['nanostructure', 'layered', 'composite']
# property = ['piezoelectricity', 'conductivity', 'hardening', 'softening', 'relaxation', 'fatigue']
# characterization = ['SEM', 'TEM', 'XRD', 'AFM', 'IR']
# preparation = ['CVD', 'PLD', 'PVD', 'MBE']
# target_words = ['material', 'application', 'mechanism', 'structure', 'property', 'characterization', 'preparation']

# # 计算余弦相似性
# similarities = {}

# # 模拟计算相似性（替换为实际模型计算相似性）
# def mock_similarity(word1, word2):
#     return np.random.rand()

# # # 计算各类别词汇与目标词汇的相似性
# # categories = {'ferroelectricity ': ferroelectricity , 'application': application, 'mechanism': mechanism,
# #               'structure': structure, 'property': property,
# #               'characterization': characterization, 'preparation': preparation}

# for target_word, category in categories.items():
#     if target_word in target_words:
#         for word in category:
#             similarities[(word, target_word)] = mock_similarity(word, target_word)

# # # 计算target_words之间的相似性
# # for i in range(len(target_words)):
# #     for j in range(i + 1, len(target_words)):
# #         word1 = target_words[i]
# #         word2 = target_words[j]
# #         similarities[(word1, word2)] = mock_similarity(word1, word2)

# # 创建图
# G = nx.Graph()

# # 添加节点
# all_words = ferroelectricity  + application + mechanism + structure + property + characterization + preparation + target_words
# for word in all_words:
#     G.add_node(word)

# # 添加边并设置宽度
# for (word1, word2), sim in similarities.items():
#     G.add_edge(word1, word2, weight=sim * 10)  # 乘以10使边的宽度更明显

# # 使用 pyvis 创建交互式图表
# net = Network(notebook=True, cdn_resources='in_line')

# # 添加节点到 pyvis 图
# for node in G.nodes:
#     label = node
#     title = node
#     if node in target_words:
#         net.add_node(node, label=label, title=title, color='skyblue', size=30)
#     else:
#         net.add_node(node, label=label, title=title, color='lightgray', size=20)

# # 添加边到 pyvis 图
# for (word1, word2, weight) in G.edges(data=True):
#     net.add_edge(word1, word2, width=weight['weight'])

# # 保存和显示图表
# net.show('ferroelectricity-knowledge-graph.html')
# # 绘制节点和标签
# # nx.draw_networkx_nodes(G, pos, nodelist=yellow_nodes, node_size=3000, node_color='skyblue')  # 设置节点颜色为黄色
# # nx.draw_networkx_nodes(G, pos, nodelist=other_nodes, node_size=3000, node_color='lightgray')  # 设置其他节点颜色
# # nx.draw_networkx_labels(G, pos, font_size=12)

# %%
# from pyvis.network import Network
# import networkx as nx
# import numpy as np

# # 定义需要计算相似性的词汇
# # 铁电材料
# ferroelectricity_words = {
#     'material': ['BaTiO3', 'PZT', 'PVDF', 'LiNbO3', 'BiFeO3'],
#     'application': ['sensors', 'actuators', 'filters', 'capacitors'],
#     'mechanism': ['polarization', 'strain', 'capacitive', 'permittivity'],
#     'structure': ['nanostructure', 'layered', 'composite'],
#     'property': ['piezoelectricity', 'conductivity', 'hardening', 'softening', 'relaxation', 'fatigue'],
#     'characterization': ['SEM', 'TEM', 'XRD', 'AFM', 'IR'],
#     'preparation': ['CVD', 'PLD', 'PVD', 'MBE']
# }

# # 超级电容器
# supercapacitors_words = {
#     'electrodes': ['carbon', 'graphitic', 'CNTs', 'RuO2', 'TiO2', 'PANI', 'polypyrrole'],
#     'electrolytes': ['H2SO4', 'KCl', 'EMIMBF4'],
#     'separator': ['cellulose', 'polypropylene'],
#     'enclosure': ['Al', 'steel'],
#     'performance': ['capacitance', 'resistance'],
#     'structure': ['nanoporous', 'microporous', 'nanostructure', 'symmetric', 'asymmetric'],
#     'characterization': ['CV', 'EIS', 'GCD', 'BET', 'SEM', 'TEM', 'XPS']
# }

# # 钙钛矿
# perovskite_words = {
#     'materials': ['CsPbBr3', 'TiO2', 'ZnO', 'CsPbI3', 'MAPbI3', 'SrTiO3', 'BiFeO3'],
#     'solvent': ['18-diiodooctane', 'NMP', 'hexane', 'DMSO', 'DMF', 'isopropyl', 'alcohol'],
#     'HTL': ['P3HT', 'WOx', 'MoO3', 'Cu2O', 'PCDTBT', 'PEDOT', 'PMMA'],
#     'ETL': ['TiO2', 'NiOx', 'Cs2CO3', 'F16CuPc', 'MoOx', 'Sb2S3', 'CuI', 'PTCDA', 'PTB7', 'ZnO', 'CuInS2'],
#     'synthesis': ['deposition', 'coating', 'annealing', 'casting'],
#     'structures': ['layered', 'nanostructure', 'nanospheres', 'multi-shelled', 'flower-like', 'nanoplates', 'porous'],
#     'crystal': ['P1', 'P2', 'P3', 'P5'],
#     'cathode': ['Ag', 'Au', 'Al'],
#     'anode': ['ITO', 'FTO', 'AZO'],
#     'property': ['hydrophilicity', 'electroactivity', 'wettability', 'biocompatibility', 'tunability']
# }

# # 锂电池
# Li_battery_words = {
#     'anode':  ['LiCoO2','LiFePO4','LiNiO2','Li2FeSiO4','Na044MnO2'],
#     'cathode': ['graphite','Li4Ti5O12'],
#     'electrolyte': ['LiPF6','LiBF4','LiNO3','LiCF3SO3','DMC','PC'],
#     'composition' : ['oxide','phosphates','sulphide'],
#     'structures' :  ['layered', 'nanostructure', 'nanospheres', 'multi-shelled', 'flower-like', 'nanoplates', 'porous'],
#     'crystal' :  ['P1', 'P2', 'P3', 'P5'],
#     'characterization': ['XRD','SEM','TEM','FTIR','XPS','UV–vis'],
#     'mechanism' :  ['alloying','dealloying','intercalation','deintercalation','desodiation','kinetically'],

# }

# ferroelectricity_center = 'ferroelectricity'
# supercapacitors_center = 'supercapacitors'
# perovskite_center = 'perovskite'
# Li_battery_center = 'battery'  # 锂电池中心词

# # 计算余弦相似性
# similarities = {}

# # 模拟计算相似性（替换为实际模型计算相似性）
# def mock_similarity(word1, word2):
#     return np.random.rand()

# # 计算ferroelectricity相关的相似性
# for target_word, words in ferroelectricity_words.items():
#     for word in words:
#         similarities[(word, target_word)] = mock_similarity(word, target_word)
#     similarities[(ferroelectricity_center, target_word)] = mock_similarity(ferroelectricity_center, target_word)

# # 计算supercapacitors相关的相似性
# for target_word, words in supercapacitors_words.items():
#     for word in words:
#         similarities[(word, target_word)] = mock_similarity(word, target_word)
#     similarities[(supercapacitors_center, target_word)] = mock_similarity(supercapacitors_center, target_word)

# # 计算perovskite相关的相似性
# for target_word, words in perovskite_words.items():
#     for word in words:
#         similarities[(word, target_word)] = mock_similarity(word, target_word)
#     similarities[(perovskite_center, target_word)] = mock_similarity(perovskite_center, target_word)

# # 计算锂电池相关的相似性
# for target_word, words in Li_battery_words.items():
#     for word in words:
#         similarities[(word, target_word)] = mock_similarity(word, target_word)
#     similarities[(Li_battery_center, target_word)] = mock_similarity(Li_battery_center, target_word)

# # 计算中心词之间的相似性
# similarities[(ferroelectricity_center, supercapacitors_center)] = mock_similarity(ferroelectricity_center, supercapacitors_center)
# similarities[(ferroelectricity_center, perovskite_center)] = mock_similarity(ferroelectricity_center, perovskite_center)
# similarities[(ferroelectricity_center, Li_battery_center)] = mock_similarity(ferroelectricity_center, Li_battery_center)
# similarities[(supercapacitors_center, perovskite_center)] = mock_similarity(supercapacitors_center, perovskite_center)
# similarities[(supercapacitors_center, Li_battery_center)] = mock_similarity(supercapacitors_center, Li_battery_center)
# similarities[(perovskite_center, Li_battery_center)] = mock_similarity(perovskite_center, Li_battery_center)

# # 创建图
# G = nx.Graph()

# # 添加节点
# all_ferroelectricity_words = [word for words in ferroelectricity_words.values() for word in words]
# all_supercapacitors_words = [word for words in supercapacitors_words.values() for word in words]
# all_perovskite_words = [word for words in perovskite_words.values() for word in words]
# all_Li_battery_words = [word for words in Li_battery_words.values() for word in words]
# all_words = all_ferroelectricity_words + all_supercapacitors_words + all_perovskite_words + all_Li_battery_words

# for word in all_words:
#     G.add_node(word)

# # 添加中心词节点
# G.add_node(ferroelectricity_center)
# G.add_node(supercapacitors_center)
# G.add_node(perovskite_center)
# G.add_node(Li_battery_center)

# # 添加边并设置宽度
# for (word1, word2), sim in similarities.items():
#     G.add_edge(word1, word2, weight=sim * 10)  # 乘以10使边的宽度更明显

# # 使用 pyvis 创建交互式图表
# net = Network(notebook=True, cdn_resources='in_line')

# # 添加节点到 pyvis 图
# for node in G.nodes:
#     label = node
#     title = node
#     if node == ferroelectricity_center:
#         net.add_node(node, label=label, title=title, color='lightgreen', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
#     elif node == supercapacitors_center:
#         net.add_node(node, label=label, title=title, color='lightpink', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
#     elif node == perovskite_center:
#         net.add_node(node, label=label, title=title, color='lightcyan', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
#     elif node == Li_battery_center:
#         net.add_node(node, label=label, title=title, color='PapayaWhip', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    
    
#     elif node in ferroelectricity_words.keys():
#         net.add_node(node, label=label, title=title, color='lightgreen', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
#     elif node in supercapacitors_words.keys():
#         net.add_node(node, label=label, title=title, color='lightpink', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
#     elif node in perovskite_words.keys():
#         net.add_node(node, label=label, title=title, color='lightcyan', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
#     elif node in Li_battery_words.keys():
#         net.add_node(node, label=label, title=title, color='PapayaWhip', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
#     else:
#         net.add_node(node, label=label, title=title, color='Thistle', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')

# # 添加边到 pyvis 图
# for (word1, word2, weight) in G.edges(data=True):
#     net.add_edge(word1, word2, width=weight['weight'])

# # 保存和显示图表
# net.show('all-knowledge-graph.html')

# %%
# 假设 `model` 是你预训练好的模型对象
similar_words = [key for key, value in model.most_similar('perovskite', topn=200)]

import re
# 定义匹配复杂化学式的正则表达式模式
chemical_formula_pattern = re.compile(r'\b[A-Z][a-z]?[A-Za-z0-9_\.]*\b')

# 存储提取的化学式
chemical_formulas = []

# 提取化学式
for word in similar_words:
    matches = chemical_formula_pattern.findall(word)
    for match in matches:
        # 过滤出有意义的化学式，忽略单个字符和数字
        if len(match) > 1 and re.search(r'[A-Za-z]', match):
            chemical_formulas.append(match)

# 去重
chemical_formulas = list(set(chemical_formulas))

# 打印所有提取到的化学式
print(chemical_formulas)
# Out:
# ['RuO_3', 'La_2Ti_2O_7', 'Bi_1', 'Ce_08Gd_02O_2', 'Popper', 'PMNT', 'SrSnO_3', 'BLFO', 'Ba_2LaSbO_6', 'LLOs', 'PVSCs', 'K_05Na_05NbO_3', 'Ca_x', 'K_2NiF_4', 'La_08Sr_02MnO_3', 'Ba_2In_2O_5', 'ZnNb_2O_6', 'Zn_2TiO_4', 'RbFeO_2', 'SrCu_2O_2', 'Pr', 'FAPbI_3', 'CsPbI_3', 'ZnMnO_3', 'Na', 'NaFeO_2', 'Ti_1', 'Sr', 'Ba', 'PrFeO_3', 'BaZrS_3', 'Ba_1', 'BNKT', 'Bi_2Ti_2O_7', 'Aurivillius', 'GaFeO_3', 'Sr_2SnO_4', 'Bi_05Na_05TiO_3', 'CaTiO_3', 'CoO_3', 'Nb', 'HTLs', 'LuFeO_3', 'SrMnO_3', 'BSZT', 'Ca', 'CaFe_2O_4', 'Yttrium', 'SmCrO_3', 'SOFC', 'LaGaO_3', 'Rh', 'IT', 'TiO_3', 'Ba_4In_2Zr_2O_11', 'Ba_2TiO_4', 'Bi_3TiNbO_9', 'YMnO_3', 'K_05Bi_45Ti_4O_15', 'Co_xO_y', 'Sr_2TiO_4', 'FeO_3', 'ZnV_2O_4', 'GdMnO_3', 'NdCoO_3', 'La_2NiO_4', 'Cu', 'SrFeO_25', 'La', 'SFMO', 'Ruddlesden', 'Perovskite', 'BaSnO_3', 'Ba_05Sr_05TiO_3', 'LaMnO_3', 'La_05Sr_05MnO_3', 'LaFeO_3', 'CaMnO_3', 'LiTi_2O_4', 'BaCeO_3', 'Sr_2FeMoO_6', 'Ce_2Zr_2O_7', 'BNT', 'O_3', 'FeMoO_6', 'BNFO', 'Ba_3Zr_2O_7', 'BiFeO_3', 'SrCuO_2', 
# ...

# %%
# 假设 `model` 是你预训练好的模型对象
similar_words = [key for key, value in model.most_similar('supercapacitors', topn=200)]

import re
# 定义匹配复杂化学式的正则表达式模式
chemical_formula_pattern = re.compile(r'\b[A-Z][a-z]?[A-Za-z0-9_\.]*\b')

# 存储提取的化学式
chemical_formulas = []

# 提取化学式
for word in similar_words:
    matches = chemical_formula_pattern.findall(word)
    for match in matches:
        # 过滤出有意义的化学式，忽略单个字符和数字
        if len(match) > 1 and re.search(r'[A-Za-z]', match):
            chemical_formulas.append(match)

# 去重
chemical_formulas = list(set(chemical_formulas))

# 打印所有提取到的化学式
print(chemical_formulas)
# Out:
# ['CNT', 'MOF', 'NCO', 'SIBs', 'NVP', 'MXene', 'FBNC', 'MnS', 'SiO_2', 'MO', 'Bi', 'PC', 'VRFBs', 'Zn', 'Co', 'NHPC', 'CoMn', 'PIn', 'GA', 'PI', 'TN', 'Li_4Ti_5O_12', 'Na', 'Li_7P_3S_11', 'Sodium', 'Supercapacitors', 'LiNi_06Co_02Mn_02O_2', 'O_2', 'LiFePO_4', 'Li_5Cr_7Ti_6O_25', 'SWCNTs', 'CoNi_2S_4', 'Na_067Ni_033Ti_067O_2', 'PG', 'Co_3O_4', 'Rechargeable', 'CNTs', 'ASSLBs', 'LiNi_05Mn_15O_4', 'MH', 'NiMH', 'CNSs', 'NiPc', 'GN', 'NiMoO_4', 'CFNCs', 'LMO', 'MWNTs', 'MOFs', 'TiO_2', 'LICs', 'Li_2NiTi_3O_8', 'POM', 'HRPSoC', 'ZABs', 'NiS', 'CQDs', 'PGCG', 'Al', 'NFG', 'PAQS', 'NIBs', 'CdMn_2O_4', 'PANI', 'KIBs', 'Pani', 'NFGH', 'TiN', 'Pb', 'Ni_067Co_033', 'TCEs', 'NiO', 'Supercapacitor', 'GMP5', 'SLIBs', 'KIB', 'Ti_3C_2T_x', 'MnO_2', 'ZIBs', 'LDH', 'Li', 'LiNi_08Co_015Zn_005O_2', 'VRLA', 'FeS_2', 'MoS_2', 'SnO_2', 'BC', 'PPy', 'LT', 'RGOA', 'Ni', 'GO', 'ZnS', 'LIBs', 'LiBs', 'PAAMPSA', 'Mg', 'COF', 'NS', 'GCPFCX', 'Fe', 'NiCo_2O_4', 'Li_2Mn_4O_9', 'HCNF', 'SnRuO', 'NiCo', 'CaTPA', 'EDL
# ...

# %%
from pyvis.network import Network
import networkx as nx
import numpy as np

# 定义需要计算相似性的词汇
# 铁电材料
ferroelectricity_words = {
    'ferroelectricity':['BaTiO3','PZT','PVDF','LiNbO3','BiFeO3','UNiGa', 'BaTiO_3', 
            'GaFeO_3', 'La_07Ce_03MnO_3', 'BFO', 'BFCO', 'TbMnO_3', 'GdMnO_3', 'Nb', 
            'Sr_2IrO_4', 'COAFM', 'PMNT', 'LHMO', 'Cu', 'PCMO', 'TaSe_2', 'Ferromagnetism',
            'TlCrSe_2', 'EuMn_2O_5', 'Colossal', 'BiMnO_3', 'LuFeO_3', 'EuTiO_3', 'BFMO',
            'Pr_06Ca_04MnO_3', 'Ferroelectrics', 'AFM', 'URhGe', 'Bi_095La_005FeO_3', 
            'Ferroelectric', 'CDW', 'BaMnF_4', 'KCa_2Fe_4As_4F_2', 'LuFe_2O_4', 'BNT', 
            'Sr_2FeMoO_6', 'BGFT_x', 'Tb_095Bi_005MnO_3', 'FM', 'YMnO_3', 'RuSr_2GdCu_2O_8', 
            'PZT', 'MFTJs', 'BiFeO_3', 'SBN', 'HoMo_6S_8', 'EFIS', 'Sr_3Ir_2O_7', 'BNKT','SmFeAsO', 'La_07Ce_03MnO_3', 'BiT', 'PbMg_1', 'La_2', 'Bi_4I_4', 'BFCO',
            'Au_2Pb', 'Bi_1', 'LaVO_3', 'TbMnO_3', 'Ho_2Ti_2O_7', 'PMNT', 'Ba_08Sr_02TiO_3', 
            'CeNiSn', 'BNTO', 'Nb_2PdS_5', 'PCMO', 'YBa_2Cu_3O_z', 'LSCO', 'FeSCs', 'CeIrIn_5', 
            'BLFO', 'FICDW', 'FeTe', 'Ba_2LaSbO_6', 'La_2NiMnO_6', 'LFMR', 'LiV_2O_4', 'Electron', 
            'BCZT', 'RTFM', 'Zn', 'Ba_09Sr_01TiO_3', 'CrBr_3', 'BLFMO', 'AFLCs', 'UCoAl', 'CDW', 
             'TlCrS_2', 'HoMnO_3', 'Prl23',
            'Berry', 'Cd_2Nb_2O_7', 'NdCu_2', 'T_a', 'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'RuSr_2GdCu_2O_8', 
            'Hf_05Zr_05O_2', 'SrBi_2Ta_2O_9', 'RuSr_2RECu_2O_8', 'YCo_5', 'Sr_2YRuO_6', 'TaP', 'Eu', 
            'La_09Sr_01MnO_3', 'PZN', 'UPd_2Al_3', 
            'PBSN', 'Sr_3Ir_2O_7', 'Nd_4MnSi_3O_13', 'Ba_02Sr_08TiO_3', 'YB_6', 'NdNiO_3'],
    'application': ['sensors', 'actuators', 'filters', 'capacitors'],
    'mechanism': ['polarization', 'strain', 'capacitive', 'permittivity'],
    'structure': ['nanostructure', 'layered', 'composite'],
    'property': ['piezoelectricity', 'conductivity', 'hardening', 'softening', 'relaxation', 'fatigue'],
    'characterization': ['SEM', 'TEM', 'XRD', 'AFM', 'IR'],
    'preparation': ['CVD', 'PLD', 'PVD', 'MBE']
}

# 超级电容器
supercapacitors_words = {
    'supercapacitors':['CNT', 'MOF', 'NCO', 'SIBs', 'NVP', 'MXene', 'FBNC', 'MnS', 'SiO_2',
                       'MO', 'Bi', 'PC', 'VRFBs', 'Zn', 'Co', 'NHPC', 'CoMn', 'PIn', 'GA', 'PI',
                       'TN', 'Li_4Ti_5O_12', 'Na', 'Li_7P_3S_11', 'Sodium', 'Supercapacitors', 
                       'LiNi_06Co_02Mn_02O_2', 'O_2', 'LiFePO_4', 'Li_5Cr_7Ti_6O_25', 'SWCNTs', 
                       'CoNi_2S_4', 'Na_067Ni_033Ti_067O_2', 'PG', 'Co_3O_4', 'Rechargeable', 'CNTs', 
                       'ASSLBs', 'LiNi_05Mn_15O_4', 'MH', 'NiMH', 'CNSs', 'NiPc', 'GN', 'NiMoO_4', 'CFNCs', 
                       'LMO', 'MWNTs', 'MOFs', 'TiO_2', 'LICs', 'Li_2NiTi_3O_8', 'POM', 'HRPSoC', 'ZABs', 
                       'NiS', 'CQDs', 'PGCG', 'Al', 'NFG', 'PAQS', 'NIBs', 'CdMn_2O_4', 'PANI', 'KIBs',
                       'Pani', 'NFGH', 'TiN', 'Pb', 'Ni_067Co_033', 'TCEs', 'NiO', 'Supercapacitor', 'GMP5', 
                       'SLIBs', 'KIB', 'Ti_3C_2T_x', 'MnO_2', 'ZIBs', 'LDH', 'Li', 'LiNi_08Co_015Zn_005O_2',
                       'VRLA', 'FeS_2', 'MoS_2', 'SnO_2', 'BC', 'PPy', 'LT', 'RGOA', 'Ni', 'GO', 'ZnS', 'LIBs',
                       'LiBs', 'PAAMPSA', 'Mg', 'COF', 'NS', 'GCPFCX', 'Fe', 'NiCo_2O_4', 'Li_2Mn_4O_9', 'HCNF',
                       'SnRuO', 'NiCo', 'CaTPA', 'EDLC', 'NRGO', 'ACHFs', 'Co_5',
                       'Lithium', 'Mn', 'AB', 'MC', 'NDMG', 'EDLCs', 'ASSBs'],
    'electrodes': ['carbon', 'graphitic', 'CNTs', 'RuO2', 'TiO2', 'PANI', 'polypyrrole'],
    'electrolytes': ['H2SO4', 'KCl', 'EMIMBF4'],
    'separator': ['cellulose', 'polypropylene'],
    'enclosure': ['Al', 'steel'],
    'performance': ['capacitance', 'resistance'],
    'structure': ['nanoporous', 'microporous', 'nanostructure', 'symmetric', 'asymmetric'],
    'characterization': ['CV', 'EIS', 'GCD', 'BET', 'SEM', 'TEM', 'XPS']
}

# 钙钛矿
perovskite_words = {
    'perovskite': ['CsPbBr3', 'TiO2', 'ZnO', 'CsPbI3', 'MAPbI3', 'SrTiO3', 'BiFeO3','RuO_3', 
                   'La_2Ti_2O_7', 'Bi_1', 'Ce_08Gd_02O_2', 'Popper', 'PMNT', 'SrSnO_3', 'BLFO',
                   'Ba_2LaSbO_6', 'LLOs', 'PVSCs', 'K_05Na_05NbO_3', 'Ca_x', 'K_2NiF_4', 'La_08Sr_02MnO_3',
                   'Ba_2In_2O_5', 'ZnNb_2O_6', 'Zn_2TiO_4', 'RbFeO_2', 'SrCu_2O_2', 'Pr', 'FAPbI_3', 'CsPbI_3',
                   'ZnMnO_3', 'Na', 'NaFeO_2', 'Ti_1', 'Sr', 'Ba', 'PrFeO_3', 'BaZrS_3', 'Ba_1', 'BNKT', 
                   'Bi_2Ti_2O_7', 'Aurivillius', 'GaFeO_3', 'Sr_2SnO_4', 'Bi_05Na_05TiO_3', 'CaTiO_3', 'CoO_3',
                   'Nb', 'HTLs', 'LuFeO_3', 'SrMnO_3', 'BSZT', 'Ca', 'CaFe_2O_4', 'Yttrium', 'SmCrO_3', 
                   'SOFC', 'LaGaO_3', 'Rh', 'IT', 'TiO_3', 'Ba_4In_2Zr_2O_11', 'Ba_2TiO_4', 'Bi_3TiNbO_9', 
                   'YMnO_3', 'K_05Bi_45Ti_4O_15', 'Co_xO_y', 'Sr_2TiO_4', 'FeO_3', 'ZnV_2O_4', 'GdMnO_3', 
                   'NdCoO_3', 'La_2NiO_4', 'Cu', 'SrFeO_25', 'La', 'SFMO', 'Ruddlesden', 'Perovskite', 'BaSnO_3',
                   'Ba_05Sr_05TiO_3', 'LaMnO_3', 'La_05Sr_05MnO_3', 'LaFeO_3', 'CaMnO_3', 'LiTi_2O_4', 'BaCeO_3',
                   'Sr_2FeMoO_6', 'Ce_2Zr_2O_7', 'BNT', 'O_3', 'FeMoO_6', 'BNFO', 'Ba_3Zr_2O_7', 'BiFeO_3',
                   'SrCuO_2', 'Na_05Bi_05TiO_3', 'Na_08K_02', 'GdFeO_3', 'BaTiO_3', 'Gd_2Hf_2O_7', 'NASICON',
                   'Pr_05Sr_05MnO_3', 'BFO', 'Na_05Bi_05', 'BaMnO_3', 'Bi_4Ti_3O_12', 'PbZrO_3', 'ABO_3', 
                   'Bi_4V_2O_11', 'LaNiO_3', 'SrFeO_3', 'MnO_3', 'LaCrO_3', 'LaCuO_3', 'La_1', 'Bi_09Eu_01FeO_3',
                   'BaBi_4Ti_4O_15', 'SrZrO_3', 'SrTi0_3', 'BaBiO_3', 'La_2Mo_2O_9', 'La_06Sr_04MnO_3', 
                   'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'A_2B_2O_7', 'Lithium', 'Hf_05Zr_05O_2', 'CsPbI_2Br', 
                   'Bi_05', 'CH_3NH_3PbI_3', 'ZrTiO_4', 'BaPbO_3'],
    'solvent': ['18-diiodooctane', 'NMP', 'hexane', 'DMSO', 'DMF', 'isopropyl', 'alcohol'],
    'HTL': ['P3HT', 'WOx', 'MoO3', 'Cu2O', 'PCDTBT', 'PEDOT', 'PMMA'],
    'ETL': ['TiO2', 'NiOx', 'Cs2CO3', 'F16CuPc', 'MoOx', 'Sb2S3', 'CuI', 'PTCDA', 'PTB7', 'ZnO', 'CuInS2'],
    'synthesis': ['deposition', 'coating', 'annealing', 'casting'],
    'structure': ['layered', 'nanostructure', 'nanospheres', 'multi-shelled', 'flower-like', 'nanoplates', 'porous'],
    'crystal': ['P1', 'P2', 'P3', 'P5'],
    'cathode': ['Ag', 'Au', 'Al'],
    'anode': ['ITO', 'FTO', 'AZO'],
    'property': ['hydrophilicity', 'electroactivity', 'wettability', 'biocompatibility', 'tunability']
}

# 锂电池
Li_battery_words = {
    'anode':  ['LiCoO2','LiFePO4','LiNiO2','Li2FeSiO4','Na044MnO2'],
    'cathode': ['graphite','Li4Ti5O12'],
    'electrolyte': ['LiPF6','LiBF4','LiNO3','LiCF3SO3','DMC','PC'],
    'composition' : ['oxide','phosphates','sulphide'],
    'structure' :  ['layered', 'nanostructure', 'nanospheres', 'multi-shelled', 'flower-like', 'nanoplates', 'porous'],
    'crystal' :  ['P1', 'P2', 'P3', 'P5'],
    'characterization': ['XRD','SEM','TEM','FTIR','XPS','UV–vis'],
    'mechanism' :  ['alloying','dealloying','intercalation','deintercalation','desodiation','kinetically'],

}

ferroelectricity_center = 'ferroelectricity'
supercapacitors_center = 'supercapacitors'
perovskite_center = 'perovskite'
Li_battery_center = 'battery'  # 锂电池中心词

# 计算余弦相似性
similarities = {}

# 模拟计算相似性（替换为实际模型计算相似性）
def mock_similarity(word1, word2):
    return np.random.rand()

# 计算ferroelectricity相关的相似性
for target_word, words in ferroelectricity_words.items():
    for word in words:
        similarities[(word, target_word)] = mock_similarity(word, target_word)
    similarities[(ferroelectricity_center, target_word)] = mock_similarity(ferroelectricity_center, target_word)

# 计算supercapacitors相关的相似性
for target_word, words in supercapacitors_words.items():
    for word in words:
        similarities[(word, target_word)] = mock_similarity(word, target_word)
    similarities[(supercapacitors_center, target_word)] = mock_similarity(supercapacitors_center, target_word)

# 计算perovskite相关的相似性
for target_word, words in perovskite_words.items():
    for word in words:
        similarities[(word, target_word)] = mock_similarity(word, target_word)
    similarities[(perovskite_center, target_word)] = mock_similarity(perovskite_center, target_word)

# 计算锂电池相关的相似性
for target_word, words in Li_battery_words.items():
    for word in words:
        similarities[(word, target_word)] = mock_similarity(word, target_word)
    similarities[(Li_battery_center, target_word)] = mock_similarity(Li_battery_center, target_word)

# 计算中心词之间的相似性
similarities[(ferroelectricity_center, supercapacitors_center)] = mock_similarity(ferroelectricity_center, supercapacitors_center)
similarities[(ferroelectricity_center, perovskite_center)] = mock_similarity(ferroelectricity_center, perovskite_center)
similarities[(ferroelectricity_center, Li_battery_center)] = mock_similarity(ferroelectricity_center, Li_battery_center)
similarities[(supercapacitors_center, perovskite_center)] = mock_similarity(supercapacitors_center, perovskite_center)
similarities[(supercapacitors_center, Li_battery_center)] = mock_similarity(supercapacitors_center, Li_battery_center)
similarities[(perovskite_center, Li_battery_center)] = mock_similarity(perovskite_center, Li_battery_center)

# 创建图
G = nx.Graph()

# 添加节点
all_ferroelectricity_words = [word for words in ferroelectricity_words.values() for word in words]
all_supercapacitors_words = [word for words in supercapacitors_words.values() for word in words]
all_perovskite_words = [word for words in perovskite_words.values() for word in words]
all_Li_battery_words = [word for words in Li_battery_words.values() for word in words]
all_words = all_ferroelectricity_words + all_supercapacitors_words + all_perovskite_words + all_Li_battery_words

for word in all_words:
    G.add_node(word)

# 添加中心词节点
G.add_node(ferroelectricity_center)
G.add_node(supercapacitors_center)
G.add_node(perovskite_center)
G.add_node(Li_battery_center)

# 添加边并设置宽度
for (word1, word2), sim in similarities.items():
    G.add_edge(word1, word2, weight=sim * 10)  # 乘以10使边的宽度更明显

# 使用 pyvis 创建交互式图表
net = Network(notebook=True, cdn_resources='in_line')

# 铁电材料颜色
ferroelectricity_color_words = ['BaTiO3','PZT','PVDF','LiNbO3','BiFeO3','UNiGa', 'BaTiO_3', 
            'GaFeO_3', 'La_07Ce_03MnO_3', 'BFO', 'BFCO', 'TbMnO_3', 'GdMnO_3', 'Nb', 
            'Sr_2IrO_4', 'COAFM', 'PMNT', 'LHMO', 'Cu', 'PCMO', 'TaSe_2', 'Ferromagnetism',
            'TlCrSe_2', 'EuMn_2O_5', 'Colossal', 'BiMnO_3', 'LuFeO_3', 'EuTiO_3', 'BFMO',
            'Pr_06Ca_04MnO_3', 'Ferroelectrics', 'AFM', 'URhGe', 'Bi_095La_005FeO_3', 
            'Ferroelectric', 'CDW', 'BaMnF_4', 'KCa_2Fe_4As_4F_2', 'LuFe_2O_4', 'BNT', 
            'Sr_2FeMoO_6', 'BGFT_x', 'Tb_095Bi_005MnO_3', 'FM', 'YMnO_3', 'RuSr_2GdCu_2O_8', 
            'PZT', 'MFTJs', 'BiFeO_3', 'SBN', 'HoMo_6S_8', 'EFIS', 'Sr_3Ir_2O_7', 'BNKT','SmFeAsO', 'La_07Ce_03MnO_3', 'BiT', 'PbMg_1', 'La_2', 'Bi_4I_4', 'BFCO',
            'Au_2Pb', 'Bi_1', 'LaVO_3', 'TbMnO_3', 'Ho_2Ti_2O_7', 'PMNT', 'Ba_08Sr_02TiO_3', 
            'CeNiSn', 'BNTO', 'Nb_2PdS_5', 'PCMO', 'YBa_2Cu_3O_z', 'LSCO', 'FeSCs', 'CeIrIn_5', 
            'BLFO', 'FICDW', 'FeTe', 'Ba_2LaSbO_6', 'La_2NiMnO_6', 'LFMR', 'LiV_2O_4', 'Electron', 
            'BCZT', 'RTFM', 'Zn', 'Ba_09Sr_01TiO_3', 'CrBr_3', 'BLFMO', 'AFLCs', 'UCoAl', 'CDW', 
             'TlCrS_2', 'HoMnO_3', 'Prl23',
            'Berry', 'Cd_2Nb_2O_7', 'NdCu_2', 'T_a', 'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'RuSr_2GdCu_2O_8', 
            'Hf_05Zr_05O_2', 'SrBi_2Ta_2O_9', 'RuSr_2RECu_2O_8', 'YCo_5', 'Sr_2YRuO_6', 'TaP', 'Eu', 
            'La_09Sr_01MnO_3', 'PZN', 'UPd_2Al_3', 
            'PBSN', 'Sr_3Ir_2O_7', 'Nd_4MnSi_3O_13', 'Ba_02Sr_08TiO_3', 'YB_6', 'NdNiO_3'
    'BaTiO3', 'PZT', 'PVDF', 'LiNbO3', 'BiFeO3',
    'sensors', 'actuators', 'filters', 'capacitors',
    'polarization', 'strain', 'capacitive', 'permittivity','nanostructure', 'layered', 'composite','piezoelectricity', 'conductivity', 'hardening', 'softening', 'relaxation', 'fatigue'
    'CVD', 'PLD', 'PVD', 'MBE']



# 超级电容器区分着色
supercapacitors__color_words = ['CNT', 'MOF', 'NCO', 'SIBs', 'NVP', 'MXene', 'FBNC', 'MnS', 'SiO_2',
                       'MO', 'Bi', 'PC', 'VRFBs', 'Zn', 'Co', 'NHPC', 'CoMn', 'PIn', 'GA', 'PI',
                       'TN', 'Li_4Ti_5O_12', 'Na', 'Li_7P_3S_11', 'Sodium', 'Supercapacitors', 
                       'LiNi_06Co_02Mn_02O_2', 'O_2', 'LiFePO_4', 'Li_5Cr_7Ti_6O_25', 'SWCNTs', 
                       'CoNi_2S_4', 'Na_067Ni_033Ti_067O_2', 'PG', 'Co_3O_4', 'Rechargeable', 'CNTs', 
                       'ASSLBs', 'LiNi_05Mn_15O_4', 'MH', 'NiMH', 'CNSs', 'NiPc', 'GN', 'NiMoO_4', 'CFNCs', 
                       'LMO', 'MWNTs', 'MOFs', 'TiO_2', 'LICs', 'Li_2NiTi_3O_8', 'POM', 'HRPSoC', 'ZABs', 
                       'NiS', 'CQDs', 'PGCG', 'Al', 'NFG', 'PAQS', 'NIBs', 'CdMn_2O_4', 'PANI', 'KIBs',
                       'Pani', 'NFGH', 'TiN', 'Pb', 'Ni_067Co_033', 'TCEs', 'NiO', 'Supercapacitor', 'GMP5', 
                       'SLIBs', 'KIB', 'Ti_3C_2T_x', 'MnO_2', 'ZIBs', 'LDH', 'Li', 'LiNi_08Co_015Zn_005O_2',
                       'VRLA', 'FeS_2', 'MoS_2', 'SnO_2', 'BC', 'PPy', 'LT', 'RGOA', 'Ni', 'GO', 'ZnS', 'LIBs',
                       'LiBs', 'PAAMPSA', 'Mg', 'COF', 'NS', 'GCPFCX', 'Fe', 'NiCo_2O_4', 'Li_2Mn_4O_9', 'HCNF',
                       'SnRuO', 'NiCo', 'CaTPA', 'EDLC', 'NRGO', 'ACHFs', 'Co_5',
                       'Lithium', 'Mn', 'AB', 'MC', 'NDMG', 'EDLCs', 'ASSBs'
                        'carbon', 'graphitic', 'CNTs', 'RuO2', 'TiO2', 'PANI', 'polypyrrole',
                        'H2SO4', 'KCl', 'EMIMBF4',
                        'cellulose', 'polypropylene',
                        'Al', 'steel','carbon','capacitance', 'resistance',
                        'nanoporous', 'microporous', 'nanostructure', 'symmetric', 'asymmetric',
                        'CV', 'EIS', 'GCD', 'BET', 'SEM', 'TEM', 'XPS']


# 钙钛矿的画成azure
perovskite_color_words = ['CsPbBr3', 'TiO2', 'ZnO', 'CsPbI3', 'MAPbI3', 'SrTiO3', 'BiFeO3','RuO_3', 
                   'La_2Ti_2O_7', 'Bi_1', 'Ce_08Gd_02O_2', 'Popper', 'PMNT', 'SrSnO_3', 'BLFO',
                   'Ba_2LaSbO_6', 'LLOs', 'PVSCs', 'K_05Na_05NbO_3', 'Ca_x', 'K_2NiF_4', 'La_08Sr_02MnO_3',
                   'Ba_2In_2O_5', 'ZnNb_2O_6', 'Zn_2TiO_4', 'RbFeO_2', 'SrCu_2O_2', 'Pr', 'FAPbI_3', 'CsPbI_3',
                   'ZnMnO_3', 'Na', 'NaFeO_2', 'Ti_1', 'Sr', 'Ba', 'PrFeO_3', 'BaZrS_3', 'Ba_1', 'BNKT', 
                   'Bi_2Ti_2O_7', 'Aurivillius', 'GaFeO_3', 'Sr_2SnO_4', 'Bi_05Na_05TiO_3', 'CaTiO_3', 'CoO_3',
                   'Nb', 'HTLs', 'LuFeO_3', 'SrMnO_3', 'BSZT', 'Ca', 'CaFe_2O_4', 'Yttrium', 'SmCrO_3', 
                   'SOFC', 'LaGaO_3', 'Rh', 'IT', 'TiO_3', 'Ba_4In_2Zr_2O_11', 'Ba_2TiO_4', 'Bi_3TiNbO_9', 
                   'YMnO_3', 'K_05Bi_45Ti_4O_15', 'Co_xO_y', 'Sr_2TiO_4', 'FeO_3', 'ZnV_2O_4', 'GdMnO_3', 
                   'NdCoO_3', 'La_2NiO_4', 'Cu', 'SrFeO_25', 'La', 'SFMO', 'Ruddlesden', 'Perovskite', 'BaSnO_3',
                   'Ba_05Sr_05TiO_3', 'LaMnO_3', 'La_05Sr_05MnO_3', 'LaFeO_3', 'CaMnO_3', 'LiTi_2O_4', 'BaCeO_3',
                   'Sr_2FeMoO_6', 'Ce_2Zr_2O_7', 'BNT', 'O_3', 'FeMoO_6', 'BNFO', 'Ba_3Zr_2O_7', 'BiFeO_3',
                   'SrCuO_2', 'Na_05Bi_05TiO_3', 'Na_08K_02', 'GdFeO_3', 'BaTiO_3', 'Gd_2Hf_2O_7', 'NASICON',
                   'Pr_05Sr_05MnO_3', 'BFO', 'Na_05Bi_05', 'BaMnO_3', 'Bi_4Ti_3O_12', 'PbZrO_3', 'ABO_3', 
                   'Bi_4V_2O_11', 'LaNiO_3', 'SrFeO_3', 'MnO_3', 'LaCrO_3', 'LaCuO_3', 'La_1', 'Bi_09Eu_01FeO_3',
                   'BaBi_4Ti_4O_15', 'SrZrO_3', 'SrTi0_3', 'BaBiO_3', 'La_2Mo_2O_9', 'La_06Sr_04MnO_3', 
                   'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'A_2B_2O_7', 'Lithium', 'Hf_05Zr_05O_2', 'CsPbI_2Br', 
                   'Bi_05', 'CH_3NH_3PbI_3', 'ZrTiO_4', 'BaPbO_3','NdNiO_3'
                    'CsPbBr3', 'TiO2', 'ZnO', 'CsPbI3', 'MAPbI3', 'SrTiO3', 'BiFeO3',
                    '18-diiodooctane', 'NMP', 'hexane', 'DMSO', 'DMF', 'isopropyl', 'alcohol',
                    'P3HT', 'WOx', 'MoO3', 'Cu2O', 'PCDTBT', 'PEDOT', 'PMMA',
                    'TiO2', 'NiOx', 'Cs2CO3', 'F16CuPc', 'MoOx', 'Sb2S3', 'CuI', 'PTCDA', 'PTB7', 'ZnO', 'CuInS2',
                    'deposition', 'coating', 'annealing', 'casting',
                    'layered', 'nanostructure', 'nanospheres', 'multi-shelled', 'flower-like', 'nanoplates', 'porous',
                    'P1', 'P2', 'P3', 'P5',
                    'Ag', 'Au', 'Al',
                    'ITO', 'FTO', 'AZO',
                    'hydrophilicity', 'electroactivity', 'wettability', 'biocompatibility', 'tunability'
]

# 锂电池着色
Li_battery__color_words = [
   'LiCoO2','LiFePO4','LiNiO2','Li2FeSiO4','Na044MnO2',
    'graphite','Li4Ti5O12',
    'LiPF6','LiBF4','LiNO3','LiCF3SO3','DMC','PC',
    'oxide','phosphates','sulphide',
    'layered', 'nanostructure', 'nanospheres', 'multi-shelled', 'flower-like', 
    'nanoplates', 'porous',
    'P1', 'P2', 'P3', 'P5',
    'XRD','SEM','TEM','FTIR','XPS','UV–vis',
    'alloying','dealloying','intercalation','deintercalation','desodiation','kinetically'

]




# 使用 pyvis 创建交互式图表
net = Network(notebook=True, cdn_resources='in_line')



# 添加节点到 pyvis 图
for node in G.nodes:
    label = node
    title = node
    
    # 画词语为颜色，为了区分
    if node in perovskite_color_words:
        net.add_node(node, label=label, title=title, color='turquoise', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in ferroelectricity_color_words:
        net.add_node(node, label=label, title=title, color='PaleGreen', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in supercapacitors__color_words:
        net.add_node(node, label=label, title=title, color='pink', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in Li_battery__color_words:
        net.add_node(node, label=label, title=title, color='bisque', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
      

    
    # 这边是中心词
    elif node == ferroelectricity_center:
        net.add_node(node, label=label, title=title, color='Green', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node == supercapacitors_center:
        net.add_node(node, label=label, title=title, color='hotpink', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node == perovskite_center:
        net.add_node(node, label=label, title=title, color='blue', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node == Li_battery_center:
        net.add_node(node, label=label, title=title, color='orange', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    
    
    elif node in ferroelectricity_words.keys():
        net.add_node(node, label=label, title=title, color='palegreen', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in supercapacitors_words.keys():
        net.add_node(node, label=label, title=title, color='lightpink', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in perovskite_words.keys():
        net.add_node(node, label=label, title=title, color='turquoise', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in Li_battery_words.keys():
        net.add_node(node, label=label, title=title, color='bisque', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    else:
        net.add_node(node, label=label, title=title, color='Thistle', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')

# 添加边到 pyvis 图
for (word1, word2, weight) in G.edges(data=True):
    net.add_edge(word1, word2, width=weight['weight'])

# 保存和显示图表
net.show('all-knowledge-graph111.html')
# Out:
# all-knowledge-graph111.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="all-knowledge-graph111.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from pyvis.network import Network
import networkx as nx
import numpy as np

# 定义需要计算相似性的词汇
material = ['BaTiO3', 'PZT', 'PVDF', 'LiNbO3', 'BiFeO3','BaTiO3','PZT','PVDF','LiNbO3','BiFeO3','UNiGa', 'BaTiO_3', 
            'GaFeO_3', 'La_07Ce_03MnO_3', 'BFO', 'BFCO', 'TbMnO_3', 'GdMnO_3', 'Nb', 
            'Sr_2IrO_4', 'COAFM', 'PMNT', 'LHMO', 'Cu', 'PCMO', 'TaSe_2', 'Ferromagnetism',
            'TlCrSe_2', 'EuMn_2O_5', 'Colossal', 'BiMnO_3', 'LuFeO_3', 'EuTiO_3', 'BFMO',
            'Pr_06Ca_04MnO_3', 'Ferroelectrics', 'AFM', 'URhGe', 'Bi_095La_005FeO_3', 
            'Ferroelectric', 'CDW', 'BaMnF_4', 'KCa_2Fe_4As_4F_2', 'LuFe_2O_4', 'BNT', 
            'Sr_2FeMoO_6', 'BGFT_x', 'Tb_095Bi_005MnO_3', 'FM', 'YMnO_3', 'RuSr_2GdCu_2O_8', 
            'PZT', 'MFTJs', 'BiFeO_3', 'SBN', 'HoMo_6S_8', 'EFIS', 'Sr_3Ir_2O_7', 'BNKT','SmFeAsO', 'La_07Ce_03MnO_3', 'BiT', 'PbMg_1', 'La_2', 'Bi_4I_4', 'BFCO',
            'Au_2Pb', 'Bi_1', 'LaVO_3', 'TbMnO_3', 'Ho_2Ti_2O_7', 'PMNT', 'Ba_08Sr_02TiO_3', 
            'CeNiSn', 'BNTO', 'Nb_2PdS_5', 'PCMO', 'YBa_2Cu_3O_z', 'LSCO', 'FeSCs', 'CeIrIn_5', 
            'BLFO', 'FICDW', 'FeTe', 'Ba_2LaSbO_6', 'La_2NiMnO_6', 'LFMR', 'LiV_2O_4', 'Electron', 
            'BCZT', 'RTFM', 'Zn', 'Ba_09Sr_01TiO_3', 'CrBr_3', 'BLFMO', 'AFLCs', 'UCoAl', 'CDW', 
             'TlCrS_2', 'HoMnO_3', 'Prl23',
            'Berry', 'Cd_2Nb_2O_7', 'NdCu_2', 'T_a', 'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'RuSr_2GdCu_2O_8', 
            'Hf_05Zr_05O_2', 'SrBi_2Ta_2O_9', 'RuSr_2RECu_2O_8', 'YCo_5', 'Sr_2YRuO_6', 'TaP', 'Eu', 
            'La_09Sr_01MnO_3', 'PZN', 'UPd_2Al_3', 
            'PBSN', 'Sr_3Ir_2O_7', 'Nd_4MnSi_3O_13', 'Ba_02Sr_08TiO_3', 'YB_6', 'NdNiO_3'
            'BaTiO3', 'PZT', 'PVDF', 'LiNbO3', 'BiFeO3']
application = ['sensors', 'actuators', 'filters', 'capacitors']
mechanism = ['polarization', 'strain', 'capacitive', 'permittivity']
structure = ['nanostructure', 'layered', 'composite']
property = ['piezoelectricity', 'conductivity', 'hardening', 'softening', 'relaxation', 'fatigue']
characterization = ['SEM', 'TEM', 'XRD', 'AFM', 'IR']
preparation = ['CVD', 'PLD', 'PVD', 'MBE']
target_words = ['material', 'application', 'mechanism', 'structure', 'property', 'characterization', 'preparation']

# 中心词
center_word = 'ferroelectricity'

# 计算余弦相似性
similarities = {}

# 模拟计算相似性（替换为实际模型计算相似性）
def mock_similarity(word1, word2):
    return np.random.rand()

# 计算各类别词汇与目标词汇的相似性
categories = {'material': material, 'application': application, 'mechanism': mechanism,
              'structure': structure, 'property': property,
              'characterization': characterization, 'preparation': preparation}

for target_word, category in categories.items():
    if target_word in target_words:
        for word in category:
            similarities[(word, target_word)] = mock_similarity(word, target_word)

# # 计算target_words之间的相似性
# for i in range(len(target_words)):
#     for j in range(i + 1, len(target_words)):
#         word1 = target_words[i]
#         word2 = target_words[j]
#         similarities[(word1, word2)] = mock_similarity(word1, word2)

# 计算中心词与target_words的相似性
for target_word in target_words:
    similarities[(center_word, target_word)] = mock_similarity(center_word, target_word)

# 创建图
G = nx.Graph()

# 添加节点
all_words = material + application + mechanism + structure + property + characterization + preparation + target_words
for word in all_words:
    G.add_node(word)

# 添加中心词节点
G.add_node(center_word)

# 添加边并设置宽度
for (word1, word2), sim in similarities.items():
    G.add_edge(word1, word2, weight=sim * 10)  # 乘以10使边的宽度更明显

# 使用 pyvis 创建交互式图表
net = Network(notebook=True, cdn_resources='in_line')

# 添加节点到 pyvis 图
for node in G.nodes:
    label = node
    title = node
    if node == center_word:
        net.add_node(node, label=label, title=title, color='lightgreen', size=60, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in target_words:
        net.add_node(node, label=label, title=title, color='skyblue', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    else:
        net.add_node(node, label=label, title=title, color='lightgray', size=30, font={'size': 15, 'align': 'middle'}, shape='circle')

# 添加边到 pyvis 图
for (word1, word2, weight) in G.edges(data=True):
    net.add_edge(word1, word2, width=weight['weight'])

# 保存和显示图表
net.show('ferroelectricity-knowledge-graph.html')
# Out:
# ferroelectricity-knowledge-graph.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="ferroelectricity-knowledge-graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
similar_words = [key for key, value in model.most_similar('anode', topn=500)]

import re
# 定义匹配复杂化学式的正则表达式模式
chemical_formula_pattern = re.compile(r'\b[A-Z][a-z]?[A-Za-z0-9_\.]*\b')

# 存储提取的化学式
chemical_formulas = []

# 提取化学式
for word in similar_words:
    matches = chemical_formula_pattern.findall(word)
    for match in matches:
        # 过滤出有意义的化学式，忽略单个字符和数字
        if len(match) > 1 and re.search(r'[A-Za-z]', match):
            chemical_formulas.append(match)

# 去重
chemical_formulas = list(set(chemical_formulas))

# 打印所有提取到的化学式
print(chemical_formulas)
# Out:
# ['CNT', 'CuCo_2S_4', 'SnO_2Ns', 'Coin', 'Ce_08Gd_02O_2', 'Half', 'SIBs', 'FeOOH', 'LLMO', 'Li_2MnSiO_4', 'LiCoO_2', 'Li_5SiN_3', 'Li_4', 'LiPON', 'PSS', 'NWs', 'CuO', 'FBNC', 'LiNi_05Mn_05O_2', 'MO', 'Bi', 'Li_12Ni_013Co_013Mn_054O_2', 'LCNT', 'Li_2CoMn_3O_8', 'PEMWE', 'NCM622', 'CuPc', 'PC', 'Galvanostatic', 'AISI316', 'VRFBs', 'Zn', 'LFNP3', 'La_08Sr_02MnO_3', 'LNCMO', 'LDOs', 'CEI', 'Co', 'GA', 'ORTA', 'Ba_05Sr_05Co_08Fe_02O_3', 'Ce_08Sm_02O_19', 'LiPSs', 'CF', 'MoO_2', 'LFP', 'TN', 'ScSZ', 'MnO2', 'Li_4Ti_5O_12', 'LiNi_08Co_016Al_004O_2', 'Na', 'Ni_02Li_02Mn_06', 'LiMn_08Fe_02PO_4', 'Li_7P_3S_11', 'B_21N_21', 'MCFCs', 'RuO2', 'MT', 'LiNi_06Co_02Mn_02O_2', 'YDB', 'O_2', 'LiFePO_4', 'AlF_3', 'Ebonex', 'HiSPEC', 'LiVPO_4F', 'AEMFC', 'Li_5Cr_7Ti_6O_25', 'Li_12Mn_056Ni_016Co_008O_2', 'Teflon', 'Charge', 'BDD', 'SOFCs', 'RVC', 'NF', 'Si_48', 'Na_067Ni_033Ti_067O_2', 'DMFCs', 'ZrO_2', 'Nb', 'Ti_4O_7', 'Co_3O_4', 'DGFC', 'DEFC', 'LiCo0_2', 'Rechargeable', 'PEFCs', 'LiAlCl_4', 'CNTs', 'Mo
# ...

# %%
similar_words = [key for key, value in model.most_similar('cathode', topn=300)]

import re
# 定义匹配复杂化学式的正则表达式模式
chemical_formula_pattern = re.compile(r'\b[A-Z][a-z]?[A-Za-z0-9_\.]*\b')

# 存储提取的化学式
chemical_formulas = []

# 提取化学式
for word in similar_words:
    matches = chemical_formula_pattern.findall(word)
    for match in matches:
        # 过滤出有意义的化学式，忽略单个字符和数字
        if len(match) > 1 and re.search(r'[A-Za-z]', match):
            chemical_formulas.append(match)

# 去重
chemical_formulas = list(set(chemical_formulas))

# 打印所有提取到的化学式
print(chemical_formulas)
# Out:
# ['CNT', 'Coin', 'Ce_08Gd_02O_2', 'Half', 'SIBs', 'LLMO', 'Li_2MnSiO_4', 'LiCoO_2', 'Li_5SiN_3', 'Li_4', 'LiPON', 'NWs', 'CuO', 'LiNi_05Mn_05O_2', 'Li_12Mn_054Ni_013Co_013O_2', 'MO', 'Bi', 'Li_12Ni_013Co_013Mn_054O_2', 'Li_2CoMn_3O_8', 'LCNT', 'PEMWE', 'NCM622', 'PC', 'AISI316', 'VRFBs', 'Zn', 'LFNP3', 'La_08Sr_02MnO_3', 'LNCMO', 'CEI', 'ORTA', 'Ce_08Sm_02O_19', 'LiPSs', 'CF', 'LFP', 'TN', 'ScSZ', 'MnO2', 'Li_4Ti_5O_12', 'Na', 'LiNiO_2', 'Ni_02Li_02Mn_06', 'LiMn_08Fe_02PO_4', 'Li_7P_3S_11', 'B_21N_21', 'LiNi_06Co_02Mn_02O_2', 'O_2', 'LiFePO_4', 'Ebonex', 'LiVPO_4F', 'Li_5Cr_7Ti_6O_25', 'Li_12Mn_056Ni_016Co_008O_2', 'Charge', 'BDD', 'SOFCs', 'Si_48', 'Na_067Ni_033Ti_067O_2', 'Nb', 'Ti_4O_7', 'DEFC', 'LiCo0_2', 'MoO_3', 'LiNi_05Mn_15O_4', 'MH', 'LTO', 'HSPE', 'SPFC', 'Al_21P_21', 'NiPc', 'LiNi_08Co_01Mn_01O_2', 'MS', 'LiNi_1', 'RuO_2', 'LiF', 'SiO', 'Cu_2O', 'Olivine', 'SOFC', 'CGO', 'TiO_2', 'IT', 'LICs', 'Li_2NiTi_3O_8', 'SOCl_2', 'Na_07MnO_205', 'HRPSoC', 'LiNi_05Co_02Mn_03O_2', 'LiN
# ...

# %%
from pyvis.network import Network
import networkx as nx
import numpy as np

# 定义需要计算相似性的词汇
# 铁电材料
ferroelectricity_words = {
    'ferroelectricity':['BaTiO3','PZT','PVDF','LiNbO3','BiFeO3','UNiGa', 'BaTiO_3', 
            'GaFeO_3', 'La_07Ce_03MnO_3', 'BFO', 'BFCO', 'TbMnO_3', 'GdMnO_3', 'Nb', 
            'Sr_2IrO_4', 'COAFM', 'PMNT', 'LHMO', 'Cu', 'PCMO', 'TaSe_2', 'Ferromagnetism',
            'TlCrSe_2', 'EuMn_2O_5', 'Colossal', 'BiMnO_3', 'LuFeO_3', 'EuTiO_3', 'BFMO',
            'Pr_06Ca_04MnO_3', 'Ferroelectrics', 'AFM', 'URhGe', 'Bi_095La_005FeO_3', 
            'Ferroelectric', 'CDW', 'BaMnF_4', 'KCa_2Fe_4As_4F_2', 'LuFe_2O_4', 'BNT', 
            'Sr_2FeMoO_6', 'BGFT_x', 'Tb_095Bi_005MnO_3', 'FM', 'YMnO_3', 'RuSr_2GdCu_2O_8', 
            'PZT', 'MFTJs', 'BiFeO_3', 'SBN', 'HoMo_6S_8', 'EFIS', 'Sr_3Ir_2O_7', 'BNKT','SmFeAsO', 'La_07Ce_03MnO_3', 'BiT', 'PbMg_1', 'La_2', 'Bi_4I_4', 'BFCO',
            'Au_2Pb', 'Bi_1', 'LaVO_3', 'TbMnO_3', 'Ho_2Ti_2O_7', 'PMNT', 'Ba_08Sr_02TiO_3', 
            'CeNiSn', 'BNTO', 'Nb_2PdS_5', 'PCMO', 'YBa_2Cu_3O_z', 'LSCO', 'FeSCs', 'CeIrIn_5', 
            'BLFO', 'FICDW', 'FeTe', 'Ba_2LaSbO_6', 'La_2NiMnO_6', 'LFMR', 'LiV_2O_4', 'Electron', 
            'BCZT', 'RTFM', 'Zn', 'Ba_09Sr_01TiO_3', 'CrBr_3', 'BLFMO', 'AFLCs', 'UCoAl', 'CDW', 
             'TlCrS_2', 'HoMnO_3', 'Prl23',
            'Berry', 'Cd_2Nb_2O_7', 'NdCu_2', 'T_a', 'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'RuSr_2GdCu_2O_8', 
            'Hf_05Zr_05O_2', 'SrBi_2Ta_2O_9', 'RuSr_2RECu_2O_8', 'YCo_5', 'Sr_2YRuO_6', 'TaP', 'Eu', 
            'La_09Sr_01MnO_3', 'PZN', 'UPd_2Al_3', 
            'PBSN', 'Sr_3Ir_2O_7', 'Nd_4MnSi_3O_13', 'Ba_02Sr_08TiO_3', 'YB_6', 'NdNiO_3'],
    'ferroelectricity_application': ['sensors', 'actuators', 'filters', 'capacitors'],
    'ferroelectricity_mechanism': ['polarization', 'strain', 'capacitive', 'permittivity'],
    'ferroelectricity_structure': ['nanostructure', 'layered', 'composite'],
    'ferroelectricity_property': ['piezoelectricity', 'conductivity', 'hardening', 'softening', 'relaxation', 'fatigue'],
    'ferroelectricity_characterization': ['SEM', 'TEM', 'XRD', 'AFM', 'IR'],
    'ferroelectricity_preparation': ['CVD', 'PLD', 'PVD', 'MBE']
 
}

# 超级电容器
supercapacitors_words = {
    'supercapacitors':['CNT', 'MOF', 'NCO', 'SIBs', 'NVP', 'MXene', 'FBNC', 'MnS', 'SiO_2',
                       'MO', 'Bi', 'PC', 'VRFBs', 'Zn', 'Co', 'NHPC', 'CoMn', 'PIn', 'GA', 'PI',
                       'TN', 'Li_4Ti_5O_12', 'Na', 'Li_7P_3S_11', 'Sodium', 'Supercapacitors', 
                       'LiNi_06Co_02Mn_02O_2', 'O_2', 'LiFePO_4', 'Li_5Cr_7Ti_6O_25', 'SWCNTs', 
                       'CoNi_2S_4', 'Na_067Ni_033Ti_067O_2', 'PG', 'Co_3O_4', 'Rechargeable', 'CNTs', 
                       'ASSLBs', 'LiNi_05Mn_15O_4', 'MH', 'NiMH', 'CNSs', 'NiPc', 'GN', 'NiMoO_4', 'CFNCs', 
                       'LMO', 'MWNTs', 'MOFs', 'TiO_2', 'LICs', 'Li_2NiTi_3O_8', 'POM', 'HRPSoC', 'ZABs', 
                       'NiS', 'CQDs', 'PGCG', 'Al', 'NFG', 'PAQS', 'NIBs', 'CdMn_2O_4', 'PANI', 'KIBs',
                       'Pani', 'NFGH', 'TiN', 'Pb', 'Ni_067Co_033', 'TCEs', 'NiO', 'Supercapacitor', 'GMP5', 
                       'SLIBs', 'KIB', 'Ti_3C_2T_x', 'MnO_2', 'ZIBs', 'LDH', 'Li', 'LiNi_08Co_015Zn_005O_2',
                       'VRLA', 'FeS_2', 'MoS_2', 'SnO_2', 'BC', 'PPy', 'LT', 'RGOA', 'Ni', 'GO', 'ZnS', 'LIBs',
                       'LiBs', 'PAAMPSA', 'Mg', 'COF', 'NS', 'GCPFCX', 'Fe', 'NiCo_2O_4', 'Li_2Mn_4O_9', 'HCNF',
                       'SnRuO', 'NiCo', 'CaTPA', 'EDLC', 'NRGO', 'ACHFs', 'Co_5',
                       'Lithium', 'Mn', 'AB', 'MC', 'NDMG', 'EDLCs', 'ASSBs'],
    'supercapacitors_electrodes': ['carbon', 'graphitic', 'CNTs', 'RuO2', 'TiO2', 'PANI', 'polypyrrole'],
    'supercapacitors_electrolytes': ['H2SO4', 'KCl', 'EMIMBF4'],
    'supercapacitors_separator': ['cellulose', 'polypropylene'],
    'supercapacitors_enclosure': ['Al', 'steel'],
    'supercapacitors_performance': ['capacitance', 'resistance'],
    'supercapacitors_structure': ['nanoporous', 'microporous', 'nanostructure', 'symmetric', 'asymmetric'],
    'supercapacitors_characterization': ['CV', 'EIS', 'GCD', 'BET', 'SEM', 'TEM', 'XPS']
}

# 钙钛矿
perovskite_words = {
    'perovskite': ['CsPbBr3', 'TiO2', 'ZnO', 'CsPbI3', 'MAPbI3', 'SrTiO3', 'BiFeO3','RuO_3', 
                   'La_2Ti_2O_7', 'Bi_1', 'Ce_08Gd_02O_2', 'Popper', 'PMNT', 'SrSnO_3', 'BLFO',
                   'Ba_2LaSbO_6', 'LLOs', 'PVSCs', 'K_05Na_05NbO_3', 'Ca_x', 'K_2NiF_4', 'La_08Sr_02MnO_3',
                   'Ba_2In_2O_5', 'ZnNb_2O_6', 'Zn_2TiO_4', 'RbFeO_2', 'SrCu_2O_2', 'Pr', 'FAPbI_3', 'CsPbI_3',
                   'ZnMnO_3', 'Na', 'NaFeO_2', 'Ti_1', 'Sr', 'Ba', 'PrFeO_3', 'BaZrS_3', 'Ba_1', 'BNKT', 
                   'Bi_2Ti_2O_7', 'Aurivillius', 'GaFeO_3', 'Sr_2SnO_4', 'Bi_05Na_05TiO_3', 'CaTiO_3', 'CoO_3',
                   'Nb', 'HTLs', 'LuFeO_3', 'SrMnO_3', 'BSZT', 'Ca', 'CaFe_2O_4', 'Yttrium', 'SmCrO_3', 
                   'SOFC', 'LaGaO_3', 'Rh', 'IT', 'TiO_3', 'Ba_4In_2Zr_2O_11', 'Ba_2TiO_4', 'Bi_3TiNbO_9', 
                   'YMnO_3', 'K_05Bi_45Ti_4O_15', 'Co_xO_y', 'Sr_2TiO_4', 'FeO_3', 'ZnV_2O_4', 'GdMnO_3', 
                   'NdCoO_3', 'La_2NiO_4', 'Cu', 'SrFeO_25', 'La', 'SFMO', 'Ruddlesden', 'Perovskite', 'BaSnO_3',
                   'Ba_05Sr_05TiO_3', 'LaMnO_3', 'La_05Sr_05MnO_3', 'LaFeO_3', 'CaMnO_3', 'LiTi_2O_4', 'BaCeO_3',
                   'Sr_2FeMoO_6', 'Ce_2Zr_2O_7', 'BNT', 'O_3', 'FeMoO_6', 'BNFO', 'Ba_3Zr_2O_7', 'BiFeO_3',
                   'SrCuO_2', 'Na_05Bi_05TiO_3', 'Na_08K_02', 'GdFeO_3', 'BaTiO_3', 'Gd_2Hf_2O_7', 'NASICON',
                   'Pr_05Sr_05MnO_3', 'BFO', 'Na_05Bi_05', 'BaMnO_3', 'Bi_4Ti_3O_12', 'PbZrO_3', 'ABO_3', 
                   'Bi_4V_2O_11', 'LaNiO_3', 'SrFeO_3', 'MnO_3', 'LaCrO_3', 'LaCuO_3', 'La_1', 'Bi_09Eu_01FeO_3',
                   'BaBi_4Ti_4O_15', 'SrZrO_3', 'SrTi0_3', 'BaBiO_3', 'La_2Mo_2O_9', 'La_06Sr_04MnO_3', 
                   'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'A_2B_2O_7', 'Lithium', 'Hf_05Zr_05O_2', 'CsPbI_2Br', 
                   'Bi_05', 'CH_3NH_3PbI_3', 'ZrTiO_4', 'BaPbO_3'],
    'solvent': ['18-diiodooctane', 'NMP', 'hexane', 'DMSO', 'DMF', 'isopropyl', 'alcohol'],
    'HTL': ['P3HT', 'WOx', 'MoO3', 'Cu2O', 'PCDTBT', 'PEDOT', 'PMMA'],
    'ETL': ['TiO2', 'NiOx', 'Cs2CO3', 'F16CuPc', 'MoOx', 'Sb2S3', 'CuI', 'PTCDA', 'PTB7', 'ZnO', 'CuInS2'],
   
    'perovskite_cathode': ['Ag', 'Au', 'Al'],
    'perovskite_anode': ['ITO', 'FTO', 'AZO'],
    'perovskite_synthesis': ['deposition', 'coating', 'annealing', 'casting'],
    'perovskite_structures': ['layered', 'nanostructure', 'nanospheres', 'multi-shelled', 'flower-like', 'nanoplates', 'porous'],
    'perovskite_crystal': ['P1', 'P2', 'P3', 'P5'],
    'perovskite_cathode': ['Ag', 'Au', 'Al'],
    'perovskite_anode': ['ITO', 'FTO', 'AZO'],
    'perovskite_property': ['hydrophilicity', 'electroactivity', 'wettability', 'biocompatibility', 'tunability']

   }

# 锂电池
Li_battery_words = {
    'Li_battery_anode':  ['LiCoO2','LiFePO4','LiNiO2','Li2FeSiO4','Na044MnO2','CNT', 'CuCo_2S_4', 
               'SnO_2Ns', 'LiCoO_2', 'LiNi_05Mn_05O_2', 'LiNi_08Co_01Mn_01O_2', 'LiNi_08Co_02Mn_02O_2', 'LiFePO_4', 'LiMnPO_4',
    'LiNi_06Co_02Mn_02O_2', 'Li_12Mn_054Ni_013Co_013O_2', 'LiNi_07Co_015Mn_015O_2', 'LiMn_08Fe_02PO_4',
    'Li_12Ni_013Co_013Mn_054O_2', 'Li_12Ni_02Mn_06O_2', 'LiNiO_2', 'LiNi_08Co_015Zn_005O_2', 'LiMn_2O_4'],
    'Li_battery_cathode': ['graphite','Li4Ti5O12','CNT', 'Li_4Ti_5O_12', 'Li_7P_3S_11', 'Li_2NiTi_3O_8', 
                'TiO_2', 'Li_2S', 'SnO_2', 'Sn', 'SiO', 'Si_48', 'Graphite'],
    'Li_battery_electrolyte': ['LiPF6','LiBF4','LiNO3','LiCF3SO3','DMC','PC'],
    'Li_battery_electrolyte': ['LiPF6','LiBF4','LiNO3','LiCF3SO3','DMC','PC'],
    'Li_battery_composition' : ['oxide','phosphates','sulphide'],
    'Li_battery_structures' :  ['layered', 'nanostructure', 'nanospheres', 'multi-shelled', 'flower-like', 'nanoplates', 'porous'],
    'Li_battery_crystal' :  ['P1', 'P2', 'P3', 'P5'],
    'Li_battery_characterization': ['XRD','SEM','TEM','FTIR','XPS','UV–vis'],
    'Li_battery_mechanism' :  ['alloying','dealloying','intercalation','deintercalation','desodiation','kinetically'],

}

ferroelectricity_center = 'ferroelectricity'
supercapacitors_center = 'supercapacitors'
perovskite_center = 'perovskite'
Li_battery_center = 'battery'  # 锂电池中心词

# 计算余弦相似性
similarities = {}

# 模拟计算相似性（替换为实际模型计算相似性）
def mock_similarity(word1, word2):
    return np.random.rand()

# 计算ferroelectricity相关的相似性
for target_word, words in ferroelectricity_words.items():
    for word in words:
        similarities[(word, target_word)] = mock_similarity(word, target_word)
    similarities[(ferroelectricity_center, target_word)] = mock_similarity(ferroelectricity_center, target_word)

# 计算supercapacitors相关的相似性
for target_word, words in supercapacitors_words.items():
    for word in words:
        similarities[(word, target_word)] = mock_similarity(word, target_word)
    similarities[(supercapacitors_center, target_word)] = mock_similarity(supercapacitors_center, target_word)

# 计算perovskite相关的相似性
for target_word, words in perovskite_words.items():
    for word in words:
        similarities[(word, target_word)] = mock_similarity(word, target_word)
    similarities[(perovskite_center, target_word)] = mock_similarity(perovskite_center, target_word)

# 计算锂电池相关的相似性
for target_word, words in Li_battery_words.items():
    for word in words:
        similarities[(word, target_word)] = mock_similarity(word, target_word)
    similarities[(Li_battery_center, target_word)] = mock_similarity(Li_battery_center, target_word)

# 计算中心词之间的相似性
similarities[(ferroelectricity_center, supercapacitors_center)] = mock_similarity(ferroelectricity_center, supercapacitors_center)
similarities[(ferroelectricity_center, perovskite_center)] = mock_similarity(ferroelectricity_center, perovskite_center)
similarities[(ferroelectricity_center, Li_battery_center)] = mock_similarity(ferroelectricity_center, Li_battery_center)
similarities[(supercapacitors_center, perovskite_center)] = mock_similarity(supercapacitors_center, perovskite_center)
similarities[(supercapacitors_center, Li_battery_center)] = mock_similarity(supercapacitors_center, Li_battery_center)
similarities[(perovskite_center, Li_battery_center)] = mock_similarity(perovskite_center, Li_battery_center)

# 创建图
G = nx.Graph()

# 添加节点
all_ferroelectricity_words = [word for words in ferroelectricity_words.values() for word in words]
all_supercapacitors_words = [word for words in supercapacitors_words.values() for word in words]
all_perovskite_words = [word for words in perovskite_words.values() for word in words]
all_Li_battery_words = [word for words in Li_battery_words.values() for word in words]
all_words = all_ferroelectricity_words + all_supercapacitors_words + all_perovskite_words + all_Li_battery_words

for word in all_words:
    G.add_node(word)

# 添加中心词节点
G.add_node(ferroelectricity_center)
G.add_node(supercapacitors_center)
G.add_node(perovskite_center)
G.add_node(Li_battery_center)

# 添加边并设置宽度
for (word1, word2), sim in similarities.items():
    G.add_edge(word1, word2, weight=sim * 10)  # 乘以10使边的宽度更明显

# 使用 pyvis 创建交互式图表
net = Network(notebook=True, cdn_resources='in_line')

# # 铁电材料颜色
# ferroelectricity_color_words = ['BaTiO3','PZT','PVDF','LiNbO3','BiFeO3','UNiGa', 'BaTiO_3', 
#             'GaFeO_3', 'La_07Ce_03MnO_3', 'BFO', 'BFCO', 'TbMnO_3', 'GdMnO_3', 'Nb', 
#             'Sr_2IrO_4', 'COAFM', 'PMNT', 'LHMO', 'Cu', 'PCMO', 'TaSe_2', 'Ferromagnetism',
#             'TlCrSe_2', 'EuMn_2O_5', 'Colossal', 'BiMnO_3', 'LuFeO_3', 'EuTiO_3', 'BFMO',
#             'Pr_06Ca_04MnO_3', 'Ferroelectrics', 'AFM', 'URhGe', 'Bi_095La_005FeO_3', 
#             'Ferroelectric', 'CDW', 'BaMnF_4', 'KCa_2Fe_4As_4F_2', 'LuFe_2O_4', 'BNT', 
#             'Sr_2FeMoO_6', 'BGFT_x', 'Tb_095Bi_005MnO_3', 'FM', 'YMnO_3', 'RuSr_2GdCu_2O_8', 
#             'PZT', 'MFTJs', 'BiFeO_3', 'SBN', 'HoMo_6S_8', 'EFIS', 'Sr_3Ir_2O_7', 'BNKT','SmFeAsO', 'La_07Ce_03MnO_3', 'BiT', 'PbMg_1', 'La_2', 'Bi_4I_4', 'BFCO',
#             'Au_2Pb', 'Bi_1', 'LaVO_3', 'TbMnO_3', 'Ho_2Ti_2O_7', 'PMNT', 'Ba_08Sr_02TiO_3', 
#             'CeNiSn', 'BNTO', 'Nb_2PdS_5', 'PCMO', 'YBa_2Cu_3O_z', 'LSCO', 'FeSCs', 'CeIrIn_5', 
#             'BLFO', 'FICDW', 'FeTe', 'Ba_2LaSbO_6', 'La_2NiMnO_6', 'LFMR', 'LiV_2O_4', 'Electron', 
#             'BCZT', 'RTFM', 'Zn', 'Ba_09Sr_01TiO_3', 'CrBr_3', 'BLFMO', 'AFLCs', 'UCoAl', 'CDW', 
#              'TlCrS_2', 'HoMnO_3', 'Prl23',
#             'Berry', 'Cd_2Nb_2O_7', 'NdCu_2', 'T_a', 'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'RuSr_2GdCu_2O_8', 
#             'Hf_05Zr_05O_2', 'SrBi_2Ta_2O_9', 'RuSr_2RECu_2O_8', 'YCo_5', 'Sr_2YRuO_6', 'TaP', 'Eu', 
#             'La_09Sr_01MnO_3', 'PZN', 'UPd_2Al_3', 
#             'PBSN', 'Sr_3Ir_2O_7', 'Nd_4MnSi_3O_13', 'Ba_02Sr_08TiO_3', 'YB_6', 'NdNiO_3'
#     'BaTiO3', 'PZT', 'PVDF', 'LiNbO3', 'BiFeO3'
#    ]



# # 超级电容器区分着色
# supercapacitors__color_words = ['CNT', 'MOF', 'NCO', 'SIBs', 'NVP', 'MXene', 'FBNC', 'MnS', 'SiO_2',
#                        'MO', 'Bi', 'PC', 'VRFBs', 'Zn', 'Co', 'NHPC', 'CoMn', 'PIn', 'GA', 'PI',
#                        'TN', 'Li_4Ti_5O_12', 'Na', 'Li_7P_3S_11', 'Sodium', 'Supercapacitors', 
#                        'LiNi_06Co_02Mn_02O_2', 'O_2', 'LiFePO_4', 'Li_5Cr_7Ti_6O_25', 'SWCNTs', 
#                        'CoNi_2S_4', 'Na_067Ni_033Ti_067O_2', 'PG', 'Co_3O_4', 'Rechargeable', 'CNTs', 
#                        'ASSLBs', 'LiNi_05Mn_15O_4', 'MH', 'NiMH', 'CNSs', 'NiPc', 'GN', 'NiMoO_4', 'CFNCs', 
#                        'LMO', 'MWNTs', 'MOFs', 'TiO_2', 'LICs', 'Li_2NiTi_3O_8', 'POM', 'HRPSoC', 'ZABs', 
#                        'NiS', 'CQDs', 'PGCG', 'Al', 'NFG', 'PAQS', 'NIBs', 'CdMn_2O_4', 'PANI', 'KIBs',
#                        'Pani', 'NFGH', 'TiN', 'Pb', 'Ni_067Co_033', 'TCEs', 'NiO', 'Supercapacitor', 'GMP5', 
#                        'SLIBs', 'KIB', 'Ti_3C_2T_x', 'MnO_2', 'ZIBs', 'LDH', 'Li', 'LiNi_08Co_015Zn_005O_2',
#                        'VRLA', 'FeS_2', 'MoS_2', 'SnO_2', 'BC', 'PPy', 'LT', 'RGOA', 'Ni', 'GO', 'ZnS', 'LIBs',
#                        'LiBs', 'PAAMPSA', 'Mg', 'COF', 'NS', 'GCPFCX', 'Fe', 'NiCo_2O_4', 'Li_2Mn_4O_9', 'HCNF',
#                        'SnRuO', 'NiCo', 'CaTPA', 'EDLC', 'NRGO', 'ACHFs', 'Co_5',
#                       ]


# # 钙钛矿的画成azure
# perovskite_color_words = ['CsPbBr3', 'TiO2', 'ZnO', 'CsPbI3', 'MAPbI3', 'SrTiO3', 'BiFeO3','RuO_3', 
#                    'La_2Ti_2O_7', 'Bi_1', 'Ce_08Gd_02O_2', 'Popper', 'PMNT', 'SrSnO_3', 'BLFO',
#                    'Ba_2LaSbO_6', 'LLOs', 'PVSCs', 'K_05Na_05NbO_3', 'Ca_x', 'K_2NiF_4', 'La_08Sr_02MnO_3',
#                    'Ba_2In_2O_5', 'ZnNb_2O_6', 'Zn_2TiO_4', 'RbFeO_2', 'SrCu_2O_2', 'Pr', 'FAPbI_3', 'CsPbI_3',
#                    'ZnMnO_3', 'Na', 'NaFeO_2', 'Ti_1', 'Sr', 'Ba', 'PrFeO_3', 'BaZrS_3', 'Ba_1', 'BNKT', 
#                    'Bi_2Ti_2O_7', 'Aurivillius', 'GaFeO_3', 'Sr_2SnO_4', 'Bi_05Na_05TiO_3', 'CaTiO_3', 'CoO_3',
#                    'Nb', 'HTLs', 'LuFeO_3', 'SrMnO_3', 'BSZT', 'Ca', 'CaFe_2O_4', 'Yttrium', 'SmCrO_3', 
#                    'SOFC', 'LaGaO_3', 'Rh', 'IT', 'TiO_3', 'Ba_4In_2Zr_2O_11', 'Ba_2TiO_4', 'Bi_3TiNbO_9', 
#                    'YMnO_3', 'K_05Bi_45Ti_4O_15', 'Co_xO_y', 'Sr_2TiO_4', 'FeO_3', 'ZnV_2O_4', 'GdMnO_3', 
#                    'NdCoO_3', 'La_2NiO_4', 'Cu', 'SrFeO_25', 'La', 'SFMO', 'Ruddlesden', 'Perovskite', 'BaSnO_3',
#                    'Ba_05Sr_05TiO_3', 'LaMnO_3', 'La_05Sr_05MnO_3', 'LaFeO_3', 'CaMnO_3', 'LiTi_2O_4', 'BaCeO_3',
#                    'Sr_2FeMoO_6', 'Ce_2Zr_2O_7', 'BNT', 'O_3', 'FeMoO_6', 'BNFO', 'Ba_3Zr_2O_7', 'BiFeO_3',
#                    'SrCuO_2', 'Na_05Bi_05TiO_3', 'Na_08K_02', 'GdFeO_3', 'BaTiO_3', 'Gd_2Hf_2O_7', 'NASICON',
#                    'Pr_05Sr_05MnO_3', 'BFO', 'Na_05Bi_05', 'BaMnO_3', 'Bi_4Ti_3O_12', 'PbZrO_3', 'ABO_3', 
#                    'Bi_4V_2O_11', 'LaNiO_3', 'SrFeO_3', 'MnO_3', 'LaCrO_3', 'LaCuO_3', 'La_1', 'Bi_09Eu_01FeO_3',
#                    'BaBi_4Ti_4O_15', 'SrZrO_3', 'SrTi0_3', 'BaBiO_3', 'La_2Mo_2O_9', 'La_06Sr_04MnO_3', 
#                    'Sr_05Ba_05Nb_2O_6', 'SrTiO_3', 'A_2B_2O_7', 'Lithium', 'Hf_05Zr_05O_2', 'CsPbI_2Br', 
#                    'Bi_05', 'CH_3NH_3PbI_3', 'ZrTiO_4', 'BaPbO_3','NdNiO_3'
#                     'CsPbBr3', 'TiO2', 'ZnO', 'CsPbI3', 'MAPbI3', 'SrTiO3', 'BiFeO3',
#                     '18-diiodooctane', 'NMP', 'hexane', 'DMSO', 'DMF', 'isopropyl', 'alcohol',
#                     'P3HT', 'WOx', 'MoO3', 'Cu2O', 'PCDTBT', 'PEDOT', 'PMMA',
#                     'TiO2', 'NiOx', 'Cs2CO3', 'F16CuPc', 'MoOx', 'Sb2S3', 'CuI', 'PTCDA', 'PTB7', 'ZnO', 'CuInS2',
#                     ]

# # 锂电池着色
# Li_battery__color_words = [
#    'LiCoO2','LiFePO4','LiNiO2','Li2FeSiO4','Na044MnO2',
#     'graphite','Li4Ti5O12',
#     'LiPF6','LiBF4','LiNO3','LiCF3SO3','graphite','Li4Ti5O12','CNT', 'Li_4Ti_5O_12', 'Li_7P_3S_11', 'Li_2NiTi_3O_8', 
#                 'TiO_2', 'Li_2S', 'SnO_2', 'Sn', 'SiO', 'Si_48', 'Graphite',
# ]




# 使用 pyvis 创建交互式图表
net = Network(notebook=True, cdn_resources='in_line')



# 添加节点到 pyvis 图
for node in G.nodes:
    label = node
    title = node
    
    # # 画词语为颜色，为了区分
    # if node in ferroelectricity_color_words:
    #     net.add_node(node, label=label, title=title, color='PaleGreen', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    # elif node in supercapacitors__color_words:
    #     net.add_node(node, label=label, title=title, color='pink', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    # elif node in perovskite_color_words:
    #     net.add_node(node, label=label, title=title, color='lightblue', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    # elif node in Li_battery__color_words:
    #     net.add_node(node, label=label, title=title, color='bisque', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
      

    
    # 这边是中心词
    # elif node == ferroelectricity_center:
        # net.add_node(node, label=label, title=title, color='Green', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    if node == ferroelectricity_center:
        net.add_node(node, label=label, title=title, color='palegreen', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node == supercapacitors_center:
        net.add_node(node, label=label, title=title, color='lightpink', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node == perovskite_center:
        net.add_node(node, label=label, title=title, color='turquoise', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node == Li_battery_center:
        net.add_node(node, label=label, title=title, color='bisque', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    
    
    elif node in ferroelectricity_words.keys():
        net.add_node(node, label=label, title=title, color='palegreen', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in supercapacitors_words.keys():
        net.add_node(node, label=label, title=title, color='lightpink', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in perovskite_words.keys():
        net.add_node(node, label=label, title=title, color='turquoise', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    elif node in Li_battery_words.keys():
        net.add_node(node, label=label, title=title, color='bisque', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')
    else:
        net.add_node(node, label=label, title=title, color='Thistle', size=50, font={'size': 15, 'align': 'middle'}, shape='circle')

# 添加边到 pyvis 图
for (word1, word2, weight) in G.edges(data=True):
    net.add_edge(word1, word2, width=weight['weight'])

# 保存和显示图表
net.show('all-knowledge-chemical-formual.html')
